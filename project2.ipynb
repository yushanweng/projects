# %% [markdown]
# #### (b) Exploring the data:

# %% [markdown]
# #### i. How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
import pandas as pd
data_1=pd.read_excel(open('Folds5x2_pp.xlsx', 'rb'),sheet_name='Sheet1')
data_1
print("9568 rows")
print("5 columns")
print("each row represents five correspondent values to the five columns")
print("each column represents different variables")
#cloumns:variables row:values
# Out:
# 9568 rows
# 5 columns
# each row represents five correspondent values to the five columns
# each column represents different variables

# %% [markdown]
# #### ii. Make pairwise scatterplots of all the varianbles in the data set including the predictors (independent variables) with the dependent variable. Describe your findings.

# %%
import matplotlib.pyplot as plt
import numpy as np
#from numpy import array
#data_1_np=data_1.to_numpy()
#data_1_np

#scatter_1=plt.scatter(data_1_np[:,0],data_1_np[:,-1],marker='o')
scatter_1=plt.scatter(x=data_1['AT'],y=data_1['PE'],marker='o')
plt.xlabel('AT')
plt.ylabel('PE')
plt.show()
scatter_2=plt.scatter(x=data_1['V'],y=data_1['PE'],marker='o')
plt.xlabel('V')
plt.ylabel('PE')
plt.show()
scatter_3=plt.scatter(x=data_1['AP'],y=data_1['PE'],marker='o')
plt.xlabel('AP')
plt.ylabel('PE')
plt.show()
scatter_4=plt.scatter(x=data_1['RH'],y=data_1['PE'],marker='o')
plt.xlabel('RH')
plt.ylabel('PE')
plt.show()
#4個圖

# %% [markdown]
# #### iii. What are the mean, the median, range, first and third quartiles, and in-terquartile ranges of each of the variables in the dataset? Summarize them in a table.

# %%
#data_1["AT"].mean()
#df_all = pd.concat([data_1,data_2,data_3,data_4,data_5], ignore_index=True)
#print(df_all)
print("AT_mean:",data_1["AT"].mean())
print("AT_median:",data_1["AT"].median())
data_1_AT_max=data_1["AT"].max()
#print("AT_max:",data_1_AT_max)
data_1_AT_min=data_1["AT"].min()
#print("AT_min:",data_1_AT_min)
the_range=data_1_AT_max-data_1_AT_min
print("AT_range:",the_range)
first_quartile=data_1["AT"].quantile([0.25])
print("AT_first quartile:",first_quartile)
third_quartile=data_1["AT"].quantile([0.75])
print("AT_third quartile:",third_quartile)
#interquartile_range=third_quartile-first_quartile
#print("interquartile range:",interquartile_range)
q75, q25 = np.percentile(data_1["AT"], [75 ,25])
iqr = q75 - q25
print("AT_interquartile range:",iqr)

print("V_mean:",data_1["V"].mean())
print("V_median:",data_1["V"].median())
data_1_V_max=data_1["V"].max()
#print("V_max:",data_1_AT_max)
data_1_V_min=data_1["V"].min()
#print("V_min:",data_1_AT_min)
the_range_V=data_1_V_max-data_1_V_min
print("V_range:",the_range_V)
first_quartile_V=data_1["V"].quantile([0.25])
print("V_first quartile:",first_quartile)
third_quartile_V=data_1["V"].quantile([0.75])
print("V_third quartile:",third_quartile_V)
#interquartile_range=third_quartile-first_quartile
#print("interquartile range:",interquartile_range)
q75_V, q25_V = np.percentile(data_1["V"], [75 ,25])
iqr_V = q75_V - q25_V
print("V_interquartile range:",iqr_V)

print("AP_mean:",data_1["AP"].mean())
print("AP_median:",data_1["AP"].median())
data_1_AP_max=data_1["AP"].max()
#print("V_max:",data_1_AT_max)
data_1_AP_min=data_1["AP"].min()
#print("V_min:",data_1_AT_min)
the_range_AP=data_1_AP_max-data_1_AP_min
print("AP_range:",the_range_AP)
first_quartile_AP=data_1["AP"].quantile([0.25])
print("AP_first quartile:",first_quartile_AP)
third_quartile_AP=data_1["AP"].quantile([0.75])
print("AP_third quartile:",third_quartile_AP)
#interquartile_range=third_quartile-first_quartile
#print("interquartile range:",interquartile_range)
q75_AP, q25_AP = np.percentile(data_1["AP"], [75 ,25])
iqr_AP = q75_AP - q25_AP
print("AP_interquartile range:",iqr_AP)

print("RH_mean:",data_1["RH"].mean())
print("RH_median:",data_1["RH"].median())
data_1_RH_max=data_1["RH"].max()
#print("V_max:",data_1_AT_max)
data_1_RH_min=data_1["RH"].min()
#print("V_min:",data_1_AT_min)
the_range_RH=data_1_RH_max-data_1_RH_min
print("RH_range:",the_range_RH)
first_quartile_RH=data_1["RH"].quantile([0.25])
print("RH_first quartile:",first_quartile_RH)
third_quartile_RH=data_1["RH"].quantile([0.75])
print("RH_third quartile:",third_quartile_RH)
#interquartile_range=third_quartile-first_quartile
#print("interquartile range:",interquartile_range)
q75_RH, q25_RH = np.percentile(data_1["RH"], [75 ,25])
iqr_RH = q75_RH - q25_RH
print("RH_interquartile range:",iqr_RH)

print("PE_mean:",data_1["PE"].mean())
print("PE_median:",data_1["PE"].median())
data_1_PE_max=data_1["PE"].max()
#print("V_max:",data_1_AT_max)
data_1_PE_min=data_1["PE"].min()
#print("V_min:",data_1_AT_min)
the_range_PE=data_1_PE_max-data_1_PE_min
print("PE_range:",the_range_PE)
first_quartile_PE=data_1["PE"].quantile([0.25])
print("PE_first quartile:",first_quartile_PE)
third_quartile_PE=data_1["PE"].quantile([0.75])
print("PE_third quartile:",third_quartile_PE)
#interquartile_range=third_quartile-first_quartile
#print("interquartile range:",interquartile_range)
q75_PE, q25_PE = np.percentile(data_1["PE"], [75 ,25])
iqr_PE = q75_PE - q25_PE
print("PE_interquartile range:",iqr_PE)

data_dict={'mean':{'AT':19.651231187290833,'V':54.30580372073601 ,'AP':1013.2590781772603 ,'RH':73.30897784280926 ,'PE':454.3650094063554 },'median':{'AT':20.345 ,'V':52.08 ,'AP':1012.94 ,'RH':74.975 ,'PE':451.54999999999995 },'range':{'AT':35.3 ,'V':56.2 ,'AP':40.40999999999997 ,'RH':74.6 ,'PE':75.5 },'first quartile':{'AT':13.51 ,'V':13.51 ,'AP':1009.1 ,'RH':63.3275 ,'PE':439.75 },'third quartile':{'AT':25.72 ,'V':66.54 ,'AP':1017.26,'RH':84.83 ,'PE':468.43 },'in-terquartile range':{'AT':12.209999999999999 ,'V':24.800000000000004 ,'AP':8.159999999999968 ,'RH':21.502499999999998 ,'PE':28.680000000000007 }}
df1=pd.DataFrame(data_dict)
df1
# Out:
# AT_mean: 19.65123118729102
# AT_median: 20.345
# AT_range: 35.3
# AT_first quartile: 0.25    13.51
# Name: AT, dtype: float64
# AT_third quartile: 0.75    25.72
# Name: AT, dtype: float64
# AT_interquartile range: 12.209999999999999
# V_mean: 54.30580372073601
# V_median: 52.08
# V_range: 56.2
# V_first quartile: 0.25    13.51
# Name: AT, dtype: float64
# V_third quartile: 0.75    66.54
# Name: V, dtype: float64
# V_interquartile range: 24.800000000000004
# AP_mean: 1013.2590781772603
# AP_median: 1012.94
# AP_range: 40.40999999999997
# AP_first quartile: 0.25    1009.1
# Name: AP, dtype: float64
# AP_third quartile: 0.75    1017.26
# Name: AP, dtype: float64
# AP_interquartile range: 8.159999999999968
# RH_mean: 73.30897784280926
# RH_median: 74.975
# RH_range: 74.6
# RH_first quartile: 0.25    63.3275
# Name: RH, dtype: float64
# RH_third quartile: 0.75    84.83
# Name: RH, dtype: float64
# RH_interquartile range: 21.502499999999998
# PE_mean: 454.3650094063554
# ...

# %% [markdown]
# #### (c) For each predictor, fit a simple linear regression model to predict the response.Describe your results. In which of the models is there a statistically significant association between the predictor and the response? Create some plots to back up your assertions. Are there any outliers that you would like to remove from your data for each of these regression tasks?

# %%
data_1_np=data_1.to_numpy()
data_1_np
# Out:
# array([[  14.96,   41.76, 1024.07,   73.17,  463.26],
#        [  25.18,   62.96, 1020.04,   59.08,  444.37],
#        [   5.11,   39.4 , 1012.16,   92.14,  488.56],
#        ...,
#        [  31.32,   74.33, 1012.92,   36.48,  429.57],
#        [  24.48,   69.45, 1013.86,   62.39,  435.74],
#        [  21.6 ,   62.52, 1017.23,   67.87,  453.28]])

# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#data_1=pd.read_excel(open('Folds5x2_pp.xlsx', 'rb'),sheet_name='Sheet1')
#data_1_np=data_1.to_numpy()
#x = data_1.iloc[:,1].values
#y = data_1.iloc[:,-1].values
x_AT=data_1_np[:,0]
x_AT=x_AT.reshape(-1,1) #column as 1 but rows as unknown
print(x_AT.shape)
y=data_1_np[:,-1]
#data_1_AT.reshape(-1, 1)
#data_1_PE.reshape(-1, 1)
x_AT_Train, x_AT_Test, yTrain, yTest = train_test_split(x_AT, y, test_size =0.7, random_state = 0)

linearRegressor = LinearRegression()
linearRegressor.fit(x_AT_Train, yTrain)
y_AT_Prediction = linearRegressor.predict(x_AT_Test)
#plt.subplot(4,2,1)
plot.scatter(x_AT_Train, yTrain, color = 'red')
plot.plot(x_AT_Train, linearRegressor.predict(x_AT_Train), color = 'blue')
plot.title('AT (Training set)')
plot.xlabel('AT')
plot.ylabel('PE')
plot.show()
#plt.subplot(4,2,2)
plot.scatter(x_AT_Test, yTest, color = 'red')
plot.plot(x_AT_Train, linearRegressor.predict(x_AT_Train), color = 'blue')
plot.title('AT (Test set)')
plot.xlabel('AT')
plot.ylabel('PE')
plot.show()

x_V=data_1_np[:,1]
x_V=x_V.reshape(-1,1) #column as 1 but rows as unknown
x_V_Train, x_V_Test, yTrain, yTest = train_test_split(x_V, y, test_size =0.7, random_state = 0)

linearRegressor = LinearRegression()
linearRegressor.fit(x_V_Train, yTrain)
y_V_Prediction = linearRegressor.predict(x_V_Test)
#plt.subplot(4,2,3)
plot.scatter(x_V_Train, yTrain, color = 'red')
plot.plot(x_V_Train, linearRegressor.predict(x_V_Train), color = 'blue')
plot.title(' V (Training set)')
plot.xlabel('V')
plot.ylabel('PE')
plot.show()
#plt.subplot(4,2,4)
plot.scatter(x_V_Test, yTest, color = 'red')
plot.plot(x_V_Train, linearRegressor.predict(x_V_Train), color = 'blue')
plot.title('V (Test set)')
plot.xlabel('V')
plot.ylabel('PE')
plot.show()

x_AP=data_1_np[:,2]
x_AP=x_AP.reshape(-1,1) #column as 1 but rows as unknown
x_AP_Train, x_AP_Test, yTrain, yTest = train_test_split(x_AP, y, test_size =0.7, random_state = 0)

linearRegressor = LinearRegression()
linearRegressor.fit(x_AP_Train, yTrain)
y_AP_Prediction = linearRegressor.predict(x_AP_Test)
#plt.subplot(4,2,3)
plot.scatter(x_AP_Train, yTrain, color = 'red')
plot.plot(x_AP_Train, linearRegressor.predict(x_AP_Train), color = 'blue')
plot.title(' AP (Training set)')
plot.xlabel('AP')
plot.ylabel('PE')
plot.show()
#plt.subplot(4,2,4)
plot.scatter(x_AP_Test, yTest, color = 'red')
plot.plot(x_AP_Train, linearRegressor.predict(x_AP_Train), color = 'blue')
plot.title('AP (Test set)')
plot.xlabel('AP')
plot.ylabel('PE')
plot.show()

x_RH=data_1_np[:,3]
x_RH=x_RH.reshape(-1,1) #column as 1 but rows as unknown
x_RH_Train, x_RH_Test, yTrain, yTest = train_test_split(x_RH, y, test_size =0.7, random_state = 0)

linearRegressor = LinearRegression()
linearRegressor.fit(x_RH_Train, yTrain)
y_RH_Prediction = linearRegressor.predict(x_RH_Test)
#plt.subplot(4,2,3)
plot.scatter(x_RH_Train, yTrain, color = 'red')
plot.plot(x_RH_Train, linearRegressor.predict(x_RH_Train), color = 'blue')
plot.title(' RH (Training set)')
plot.xlabel('RH')
plot.ylabel('PE')
plot.show()
#plt.subplot(4,2,4)
plot.scatter(x_RH_Test, yTest, color = 'red')
plot.plot(x_RH_Train, linearRegressor.predict(x_RH_Train), color = 'blue')
plot.title('RH (Test set)')
plot.xlabel('RH')
plot.ylabel('PE')
plot.show()
#4個圖
# Out:
# (9568, 1)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression

#X = np.array([[10, 80], [8, 0], [8, 200], [5, 200], [7, 300], [8, 230], [7, 40], [9, 0], [6, 330], [9, 180]])
#y = np.array([469, 366, 371, 208, 246, 297, 363, 436, 198, 364])

att = LinearRegression()
att.fit(x_AT_Train,yTrain)
# 印出 p-value
print(f_regression(x_AT_Train,yTrain)[1])

v = LinearRegression()
v.fit(x_V_Train,yTrain)
# 印出 p-value
print(f_regression(x_V_Train,yTrain)[1])

ap = LinearRegression()
ap.fit(x_AP_Train,yTrain)
# 印出 p-value
print(f_regression(x_AP_Train,yTrain)[1])

rh = LinearRegression()
rh.fit(x_RH_Train,yTrain)
# 印出 p-value
print(f_regression(x_RH_Train,yTrain)[1])
# Out:
# [0.]
# [0.]
# [2.70417742e-213]
# [1.13486916e-108]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
#np.random.seed(1)

# fake up some data
#spread = np.random.rand(50) * 100
#center = np.ones(25) * 50
#flier_high = np.random.rand(10) * 100 + 100
#flier_low = np.random.rand(10) * -100
# 将多个array按指定axis（默认为0）合并
#data = xTrain
#label_x=['pelvic incidence', 'pelvic tilt', 'lumbar lordosis angle',
#'sacral slope', 'pelvic radius','grade of spondylolisthesis']
fig1, ax1 = plt.subplots()
ax1.set_title('AT Box Plot')
ax1.boxplot(x_AT_Train, 
            showmeans=False, # 显示均值
            showfliers=True, # 显示异常点
            flierprops=dict(markerfacecolor='g', marker='D'), # 异常值样式
            notch=False, # 默认95%的置信区间，在中值附近
            patch_artist=True, #使用自定义颜色填充盒形图，一定要先设置才可以定义颜色
            boxprops = {'color':'black','facecolor':'lightgrey'}, 
            whis=0.75
           )

fig2, ax2 = plt.subplots()
ax2.set_title('V Box Plot')
ax2.boxplot(x_V_Train, 
            showmeans=False, # 显示均值
            showfliers=True, # 显示异常点
            flierprops=dict(markerfacecolor='g', marker='D'), # 异常值样式
            notch=False, # 默认95%的置信区间，在中值附近
            patch_artist=True, #使用自定义颜色填充盒形图，一定要先设置才可以定义颜色
            boxprops = {'color':'black','facecolor':'lightgrey'}, 
            whis=0.75
           )
fig3, ax3 = plt.subplots()
ax3.set_title('AP Box Plot')
ax3.boxplot(x_AP_Train, 
            showmeans=False, # 显示均值
            showfliers=True, # 显示异常点
            flierprops=dict(markerfacecolor='g', marker='D'), # 异常值样式
            notch=False, # 默认95%的置信区间，在中值附近
            patch_artist=True, #使用自定义颜色填充盒形图，一定要先设置才可以定义颜色
            boxprops = {'color':'black','facecolor':'lightgrey'}, 
            whis=0.75
           )

fig4, ax4 = plt.subplots()
ax4.set_title('RH Box Plot')
ax4.boxplot(x_RH_Train, 
            showmeans=False, # 显示均值
            showfliers=True, # 显示异常点
            flierprops=dict(markerfacecolor='g', marker='D'), # 异常值样式
            notch=False, # 默认95%的置信区间，在中值附近
            patch_artist=True, #使用自定义颜色填充盒形图，一定要先设置才可以定义颜色
            boxprops = {'color':'black','facecolor':'lightgrey'}, 
            whis=0.75
           )
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x1c15f8ce80>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c15f80710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1c15faf3c8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1c15f80f60>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1c15f80128>,
#   <matplotlib.lines.Line2D at 0x1c15f80278>]}

# %% [markdown]
# #### (d) Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis H0 : βj = 0?

# %%
#X=pd_data.loc[:,('中证500','泸深300','上证50','上证180')]
#y=pd_data.loc[:,'上证指数']
x=data_1.loc[:,('AT','V','AP','RH')]
y=data_1.loc[:,('PE')]
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size =0.7, random_state = 0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)
yPrediction = linearRegressor.predict(xTest)
print (yPrediction)

ml = LinearRegression()
ml.fit(xTrain,yTrain)
# 印出 p-value
print("p-value:",f_regression(xTrain,yTrain)[1])
print("every p-value<0.05 => reject all")
#p value 4個 reject<0.05  (全部reject)
# Out:
# [431.41828755 458.77040635 462.98109075 ... 445.83715748 433.38282731
#  445.25644229]
# p-value: [0.00000000e+000 0.00000000e+000 2.70417742e-213 1.13486916e-108]
# every p-value<0.05 => reject all

# %% [markdown]
# #### (e) How do your results from 1c compare to your results from 1d? Create a plot displaying the univariate regression coefficients from 1c on the x-axis, and the multiple regression coefficients from 1d on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coefficient in a simple linear regression model is shown on the x-axis, and its coefficient estimate in the multiple linear regression model is shown on the y-axis.

# %%
print("AT_coef:",att.coef_) 
print("V_coef:",v.coef_)
print("AP_coef:",ap.coef_)
print("RH_coef:",rh.coef_)
print("ML_coef:",ml.coef_)
# Out:
# AT_coef: [-2.14451702]
# V_coef: [-1.15477896]
# AP_coef: [1.51493694]
# RH_coef: [0.46057972]
# ML_coef: [-1.89397322 -0.26400557  0.08195189 -0.15147645]

# %%
plt.plot([-2.14451702,-1.15477896, 1.51493694,0.46057972], [-1.89397322,-0.26400557,0.08195189,-0.15147645], 'bo')
#plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# #### (f) Is there evidence of nonlinear association between any of the predictors and the response? To answer this question, for each predictor X, fit a model of the form1 Y = β0 + β1X + β2X^2 + β3X^3 +ε¶

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import matplotlib.pyplot as plt

#x_AT=data_1_np[:,0]
#y=data_1_np[:,-1]

#x_AT=x_AT.reshape(-1,1)
poly = PolynomialFeatures(degree=3)
#print(poly.fit_transform(x_AT))
poly_at=poly.fit_transform(x_AT)
poly.fit(poly_at,y)

linearRegressor = LinearRegression()
linearRegressor.fit(poly_at,y)
yPredict_at= linearRegressor.predict(poly_at)
print (yPredict_at)
plt.scatter(x_AT, y, color = 'yellow')
plt.scatter(x_AT, linearRegressor.predict(poly_at), color = 'blue')
plot.title('AT polynomial regression')
plot.xlabel('AT(poly)')
plot.ylabel('PE')
plot.show()

poly_v = PolynomialFeatures(degree=3)
#print(poly_2.fit_transform(x_V))
poly_v=poly.fit_transform(x_V)
poly.fit(poly_v,y)
linearRegressor = LinearRegression()
linearRegressor.fit(poly_v,y)
yPredict_v= linearRegressor.predict(poly_v)
print (yPredict_v)
plt.scatter(x_V, y, color = 'yellow')
plt.scatter(x_V, linearRegressor.predict(poly_v), color = 'blue')
plot.title('V polynomial regression')
plot.xlabel('V(poly)')
plot.ylabel('PE')
plot.show()

poly_ap= PolynomialFeatures(degree=3)
#print(poly_3.fit_transform(x_AP))
poly_ap=poly.fit_transform(x_AP)
poly.fit(poly_ap,y)
linearRegressor = LinearRegression()
linearRegressor.fit(poly_ap,y)
yPredict_ap= linearRegressor.predict(poly_ap)
print (yPredict_ap)
plt.scatter(x_AP, y, color = 'yellow')
plt.scatter(x_AP, linearRegressor.predict(poly_ap), color = 'blue')
plot.title('AP polynomial regression')
plot.xlabel('AP(poly)')
plot.ylabel('PE')
plot.show()

poly_rh= PolynomialFeatures(degree=3)
#print(poly_4.fit_transform(x_RH))
poly_rh=poly.fit_transform(x_RH)
poly.fit(poly_rh,y)
linearRegressor = LinearRegression()
linearRegressor.fit(poly_rh,y)
yPredict_rh= linearRegressor.predict(poly_rh)
print (yPredict_rh)
plt.scatter(x_RH, y, color = 'yellow')
plt.scatter(x_RH, linearRegressor.predict(poly_rh), color = 'blue')
plot.title('RH polynomial regression')
plot.xlabel('RH(poly)')
plot.ylabel('PE')
plot.show()
# Out:
# [464.54684395 440.72181915 486.69856923 ... 433.03855824 442.03572569
#  448.11655276]
# [469.65228348 441.9171009  473.66562173 ... 434.94640782 437.14439759
#  442.31226296]
# [473.18603866 466.88248064 450.98309091 ... 452.42145112 454.27784591
#  461.26891058]
# [454.36925312 447.06920305 462.94065403 ... 440.72208905 448.6940829
#  451.54461504]

# %% [markdown]
# #### (g) Is there evidence of association of interactions of predictors with the response? To answer this question, run a full linear regression model with all pairwise interaction terms and state whether any interaction terms are statistically significant.

# %%
list_inter=[data_1_np[:,0],data_1_np[:,1],data_1_np[:,2],data_1_np[:,3]]
list_inter2=[data_1_np[:,0],data_1_np[:,1],data_1_np[:,2],data_1_np[:,3]]
list_interact=[]
list_interact.append(data_1_np[:,0])
list_interact.append(data_1_np[:,1])
list_interact.append(data_1_np[:,2])
list_interact.append(data_1_np[:,3]) 

for i in range(len(list_inter)):
    for j in range(len(list_inter2)): 
        if i!=j and i<j:
            list_interact.append(list_inter[i]*list_inter2[j])
            print(list_interact)  
list_interact
# Out:
# [array([14.96, 25.18,  5.11, ..., 31.32, 24.48, 21.6 ]), array([41.76, 62.96, 39.4 , ..., 74.33, 69.45, 62.52]), array([1024.07, 1020.04, 1012.16, ..., 1012.92, 1013.86, 1017.23]), array([73.17, 59.08, 92.14, ..., 36.48, 62.39, 67.87]), array([ 624.7296, 1585.3328,  201.334 , ..., 2328.0156, 1700.136 ,
#        1350.432 ])]
# [array([14.96, 25.18,  5.11, ..., 31.32, 24.48, 21.6 ]), array([41.76, 62.96, 39.4 , ..., 74.33, 69.45, 62.52]), array([1024.07, 1020.04, 1012.16, ..., 1012.92, 1013.86, 1017.23]), array([73.17, 59.08, 92.14, ..., 36.48, 62.39, 67.87]), array([ 624.7296, 1585.3328,  201.334 , ..., 2328.0156, 1700.136 ,
#        1350.432 ]), array([15320.0872, 25684.6072,  5172.1376, ..., 31724.6544, 24819.2928,
#        21972.168 ])]
# ...

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression

#x=data_1.loc[:,('AT','V','AP','RH')]
#list_interact = []

x_inter=np.array(list_interact)

#y=data_1.loc[:,('PE')]
#xTrain_inter, xTest_inter, yTrain, yTest = train_test_split(x_inter, y, test_size =0.7, random_state = 0) #每次都填1，其他引數一樣的情況下你得到的隨機陣列是一樣的。但填0或不填，每次都會不一樣
#for i in range(len(x_inter)):
linearRegressor = LinearRegression()
linearRegressor.fit(x_inter.T,y)
yPrediction_inter = linearRegressor.predict(x_inter.T)
#print (yPrediction_inter)

# 印出 p-value

#print("p-value:",f_regression(x_inter.T,y)[1])

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std

#np.random.seed(9876789)
#nsample = 100
#x = np.linspace(0, 10, 100)
#X = np.column_stack((x, x**2))
#beta = np.array([1, 0.1, 10])
#e = np.random.normal(size=nsample)
sm_x = sm.add_constant(x_inter.T)
#y = np.dot(X, beta) + e
model = sm.OLS(y, sm_x)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                 1.405e+04
# Date:                Tue, 24 Sep 2019   Prob (F-statistic):               0.00
# Time:                        23:05:27   Log-Likelihood:                -27548.
# No. Observations:                9568   AIC:                         5.512e+04
# Df Residuals:                    9557   BIC:                         5.520e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        685.7825     78.640      8.721      0.000     531.631     839.934
# ...

# %%
print("reject: x2(V) x5(AT*V) x7(AT*RH) x8(V*AP)") #ask
# Out:
# reject: x2(V) x5(AT*V) x7(AT*RH) x8(V*AP)

# %% [markdown]
# #### (h) Can you improve your model using possible interaction terms or nonlinear asso-ciations between the predictors and response? Train the regression model on a randomly selected 70% subset of the data with all predictors. Also, run a regres-sion model involving all possible interaction terms and quadratic nonlinearities, and remove insignificant variables using p-values (be careful about interaction terms). Test both models on the remaining points and report your train and test MSEs.

# %%
h_4=[]
h_4.append(data_1_np[:,0])
h_4.append(data_1_np[:,1])
h_4.append(data_1_np[:,2])
h_4.append(data_1_np[:,3])
h_4
# Out:
# [array([14.96, 25.18,  5.11, ..., 31.32, 24.48, 21.6 ]),
#  array([41.76, 62.96, 39.4 , ..., 74.33, 69.45, 62.52]),
#  array([1024.07, 1020.04, 1012.16, ..., 1012.92, 1013.86, 1017.23]),
#  array([73.17, 59.08, 92.14, ..., 36.48, 62.39, 67.87])]

# %%
h_4_np=np.array(h_4)

xTrain_4, xTest_4, yTrain_4, yTest_4 = train_test_split(x, y, test_size =0.3, random_state = 0)
linearRegressor = LinearRegression()
linearRegressor.fit(xTrain_4,yTrain_4)
yPrediction_4tr = linearRegressor.predict(xTrain_4)
train_error_4=mean_squared_error(yTrain_4,yPrediction_4tr)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain_4,yTrain_4)
yPrediction_4te = linearRegressor.predict(xTest_4)
test_error_4=mean_squared_error(yTest_4,yPrediction_4te)

sm_x4 = sm.add_constant(h_4_np.T)
model4 = sm.OLS(y, sm_x4)
results4 = model4.fit()
print(results4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Wed, 25 Sep 2019   Prob (F-statistic):               0.00
# Time:                        20:20:43   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# ...

# %%
train_error_4=mean_squared_error(yTrain_4,yPrediction_4tr)
print("train error:",train_error_4)
# Out:
# train error: 20.941563616739593

# %%
test_error_4=mean_squared_error(yTest_4,yPrediction_4te)
print("test error:",test_error_4)
# Out:
# test error: 20.36838300288591

# %%
list_h=[data_1_np[:,0],data_1_np[:,1],data_1_np[:,2],data_1_np[:,3]]
list_h2=[data_1_np[:,0],data_1_np[:,1],data_1_np[:,2],data_1_np[:,3]]

list_interh=[]
list_interh.append(data_1_np[:,0])
list_interh.append(data_1_np[:,1])
list_interh.append(data_1_np[:,2])
list_interh.append(data_1_np[:,3]) 

for i in range(len(list_h)):
    for j in range(len(list_h2)): 
        if j>=i:
            list_interh.append(list_h[i]*list_h2[j])
            print(list_interh)
list_interh
# Out:
# [array([14.96, 25.18,  5.11, ..., 31.32, 24.48, 21.6 ]), array([41.76, 62.96, 39.4 , ..., 74.33, 69.45, 62.52]), array([1024.07, 1020.04, 1012.16, ..., 1012.92, 1013.86, 1017.23]), array([73.17, 59.08, 92.14, ..., 36.48, 62.39, 67.87]), array([223.8016, 634.0324,  26.1121, ..., 980.9424, 599.2704, 466.56  ])]
# [array([14.96, 25.18,  5.11, ..., 31.32, 24.48, 21.6 ]), array([41.76, 62.96, 39.4 , ..., 74.33, 69.45, 62.52]), array([1024.07, 1020.04, 1012.16, ..., 1012.92, 1013.86, 1017.23]), array([73.17, 59.08, 92.14, ..., 36.48, 62.39, 67.87]), array([223.8016, 634.0324,  26.1121, ..., 980.9424, 599.2704, 466.56  ]), array([ 624.7296, 1585.3328,  201.334 , ..., 2328.0156, 1700.136 ,
#        1350.432 ])]
# ...

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#x=data_1.loc[:,('AT','V','AP','RH')]
#list_interact = []

x_interh=np.array(list_interh)
#print(len(x_interh),len(y))
#y=data_1.loc[:,('PE')]
xTrain_interh, xTest_interh, yTrain_interh, yTest_interh = train_test_split(x, y, test_size =0.3, random_state = 0) #每次都填1，其他引數一樣的情況下你得到的隨機陣列是一樣的。但填0或不填，每次都會不一樣
#for i in range(len(x_inter)):
linearRegressor = LinearRegression()
linearRegressor.fit(xTrain_interh,yTrain_interh)
yPrediction_interh = linearRegressor.predict(xTrain_interh)
train_error=mean_squared_error(yTrain_interh,yPrediction_interh)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain_interh,yTrain_interh)
yPrediction_interh_te = linearRegressor.predict(xTest_interh)
test_error=mean_squared_error(yTest_interh,yPrediction_interh_te)

sm_xh = sm.add_constant(x_interh.T)
modelh = sm.OLS(y, sm_xh)
resultsh = modelh.fit()
print(resultsh.summary())
#print("Mean squared error: %.2f"
   # % mean_squared_error(diabetes_y_test, diabetes_y_pred))
#print (yPrediction_inter)

# 印出 p-value

#print("p-value:",f_regression(x_interh.T,y)[1])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.030e+04
# Date:                Wed, 25 Sep 2019   Prob (F-statistic):               0.00
# Time:                        20:05:39   Log-Likelihood:                -27431.
# No. Observations:                9568   AIC:                         5.489e+04
# Df Residuals:                    9553   BIC:                         5.500e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7503.7323   1207.276     -6.215      0.000   -9870.250   -5137.214
# ...

# %%
#print("x3(AP) x4(RH) x5(AT*AT) x6(AT*V) x8(AT*RH) x12(AP*AT) x13(AP*RH) x14(RH*RH)")
# Out:
# reject: x3(AP) x4(RH) x5(AT*AT) x6(AT*V) x8(AT*RH) x12(AP*AT) x13(AP*RH) x14(RH*RH)

# %%
train_error=mean_squared_error(yTrain_interh,yPrediction_interh)
train_error
# Out:
# 20.941563616739593

# %%
test_error=mean_squared_error(yTest_interh,yPrediction_interh_te)
test_error
# Out:
# 20.36838300288591

# %% [markdown]
# #### (i) KNN Regression: i. Perform k-nearest neighbor regression for this dataset using both normalized and raw features. Find the value of k ∈ {1, 2, . . . , 100} that gives you the best fit. Plot the train and test errors in terms of 1/k.

# %%
x=data_1_np[:,:-1]
x
# Out:
# array([[  14.96,   41.76, 1024.07,   73.17],
#        [  25.18,   62.96, 1020.04,   59.08],
#        [   5.11,   39.4 , 1012.16,   92.14],
#        ...,
#        [  31.32,   74.33, 1012.92,   36.48],
#        [  24.48,   69.45, 1013.86,   62.39],
#        [  21.6 ,   62.52, 1017.23,   67.87]])

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
listtt_tr=[]
x=data_1_np[:,:-1]
#x=x.reshape(-1,1) #column as 1 but rows as unknown
#print(x_AT.shape)
y=data_1_np[:,-1]
#data_1_AT.reshape(-1, 1)
#data_1_PE.reshape(-1, 1)
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size =0.7, random_state = 0)

for i in range(1,101):
    neigh = KNeighborsRegressor(n_neighbors=i)
    print("k=",i)
    neigh.fit(xTrain,yTrain) 
    #KNeighborsRegressor(...)
    predict_tr=neigh.predict(xTrain)
    print(predict_tr)
    #x=predict-test
    x_tr=predict_tr-yTrain
    print(abs(x_tr))
    abs_x_tr=abs(x_tr)
    print(abs_x_tr.sum())
    sum_abs_x_tr=abs_x_tr.sum()
    b_tr=sum_abs_x_tr.astype(int)
    listtt_tr.append(b_tr)
print(listtt_tr)  

min_value_tr=0
for i in range (len(listtt_tr)-1):
    if listtt_tr[i]<listtt_tr[i+1]:
        tmp_tr = listtt_tr[i]
        listtt_tr[i] = listtt_tr[i+1]
        listtt_tr[i+1] = tmp_tr
        min_value_tr=tmp_tr
print("most suitable k (train errors):k=1")        
print(min_value_tr)
# Out:
# k= 1
# [477.57 439.75 478.38 ... 459.01 462.72 428.12]
# [0. 0. 0. ... 0. 0. 0.]
# 0.0
# k= 2
# [477.355 441.66  480.155 ... 464.73  463.42  428.88 ]
# [0.215 1.91  1.775 ... 5.72  0.7   0.76 ]
# 5240.304999999999
# k= 3
# [476.62666667 437.42       479.00666667 ... 464.79666667 462.63
#  430.63333333]
# [0.94333333 2.33       0.62666667 ... 5.78666667 0.09       2.51333333]
# 6474.6
# k= 4
# [475.9375 435.3925 476.3475 ... 465.72   465.845  430.1425]
# [1.6325 4.3575 2.0325 ... 6.71   3.125  2.0225]
# 7218.325000000003
# k= 5
# [474.94  435.31  477.002 ... 466.35  465.536 430.052]
# [2.63  4.44  1.378 ... 7.34  2.816 1.932]
# 7691.878000000001
# k= 6
# [476.47       434.44333333 475.68666667 ... 465.74166667 467.81666667
#  429.92833333]
# [1.1        5.30666667 2.69333333 ... 6.73166667 5.09666667 1.80833333]
# 8066.696666666667
# k= 7
# [478.09571429 433.73142857 474.62714286 ... 465.72714286 467.54
#  429.76285714]
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
listtt_te=[]
x=data_1_np[:,:-1]
#x=x.reshape(-1,1) #column as 1 but rows as unknown
#print(x_AT.shape)
y=data_1_np[:,-1]
#data_1_AT.reshape(-1, 1)
#data_1_PE.reshape(-1, 1)
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size =0.7, random_state = 0)

for i in range(1,101):
    neigh = KNeighborsRegressor(n_neighbors=i)
    print("k=",i)
    neigh.fit(xTrain,yTrain) 
    #KNeighborsRegressor(...)
    predict_te=neigh.predict(xTest)
    print(predict_te)
    #x=predict-test
    x_te=predict_te-yTest
    print(abs(x_te))
    abs_x_te=abs(x_te)
    print(abs_x_te.sum())
    sum_abs_x_te=abs_x_te.sum()
    b_te=sum_abs_x_te.astype(int)
    listtt_te.append(b_te)
print(listtt_te)  

min_value_te=0
for i in range (len(listtt_te)-1):
    if listtt_te[i]<listtt_te[i+1]:
        tmp_te = listtt_te[i]
        listtt_te[i] = listtt_te[i+1]
        listtt_te[i+1] = tmp_te
        min_value_te=tmp_te
print("most suitable k (test errors):k=3")        
print(min_value_te)
# Out:
# k= 1
# [432.67 458.78 462.21 ... 454.13 430.91 443.82]
# [1.44 1.23 1.07 ... 1.82 0.85 1.39]
# 24533.809999999998
# k= 2
# [434.575 456.655 466.14  ... 452.9   428.89  443.86 ]
# [3.345 3.355 5.    ... 0.59  1.17  1.35 ]
# 22679.749999999996
# k= 3
# [433.59       457.28       466.61       ... 452.66666667 428.87666667
#  444.08333333]
# [2.36       2.73       5.47       ... 0.35666667 1.18333333 1.12666667]
# 22394.566666666666
# k= 4
# [432.3075 455.305  469.205  ... 453.345  429.9675 445.005 ]
# [1.0775 4.705  8.065  ... 1.035  0.0925 0.205 ]
# 22422.995
# k= 5
# [432.974 454.092 470.922 ... 453.032 429.116 444.57 ]
# [1.744 5.918 9.782 ... 0.722 0.944 0.64 ]
# 22598.519999999993
# k= 6
# [432.87       454.605      470.17166667 ... 453.30666667 430.45333333
#  443.265     ]
# [1.64       5.405      9.03166667 ... 0.99666667 0.39333333 1.945     ]
# 22692.69833333333
# k= 7
# [433.02285714 456.39857143 469.87428571 ... 453.46857143 430.67428571
#  443.00428571]
# ...

# %%
k_value=[]
for i in range(1,101,1):
    #k_value.append(i**-1)
    k_value+=[i**-1]
k_value
# Out:
# [1.0,
#  0.5,
#  0.3333333333333333,
#  0.25,
#  0.2,
#  0.16666666666666666,
#  0.14285714285714285,
#  0.125,
#  0.1111111111111111,
#  0.1,
#  0.09090909090909091,
#  0.08333333333333333,
#  0.07692307692307693,
#  0.07142857142857142,
#  0.06666666666666667,
#  0.0625,
#  0.058823529411764705,
#  0.05555555555555555,
#  0.05263157894736842,
#  0.05,
#  0.047619047619047616,
#  0.045454545454545456,
#  0.043478260869565216,
#  0.041666666666666664,
#  0.04,
#  0.038461538461538464,
#  0.037037037037037035,
#  0.03571428571428571,
#  0.034482758620689655,
#  0.03333333333333333,
#  0.03225806451612903,
#  0.03125,
#  0.030303030303030304,
#  0.029411764705882353,
#  0.02857142857142857,
#  0.027777777777777776,
#  0.02702702702702703,
#  0.02631578947368421,
#  0.02564102564102564,
#  0.025,
#  0.024390243902439025,
#  0.023809523809523808,
#  0.023255813953488372,
#  0.022727272727272728,
#  0.022222222222222223,
#  0.021739130434782608,
#  0.02127659574468085,
# ...

# %%
normalized=[]
# Select only the numeric columns from the NBA dataset
at_numeric =data_1["AT"]
# Normalize all of the numeric columns
at_numeric_normalized = (at_numeric - at_numeric.mean()) / at_numeric.std() #什麼東西normalized 寫4行 再合起來 用空的list append
normalized.append(at_numeric_normalized)
v_numeric =data_1["V"]
v_numeric_normalized = (v_numeric - v_numeric.mean()) / v_numeric.std()
normalized.append(v_numeric_normalized)
ap_numeric =data_1["AP"]
ap_numeric_normalized = (ap_numeric - ap_numeric.mean()) / ap_numeric.std()
normalized.append(ap_numeric_normalized)
rh_numeric =data_1["RH"]
rh_numeric_normalized = (rh_numeric - rh_numeric.mean()) / rh_numeric.std()
normalized.append(rh_numeric_normalized)
print(at_numeric_normalized)
print(v_numeric_normalized)
print(ap_numeric_normalized)
print(rh_numeric_normalized)
print(normalized)
# Out:
# 0      -0.629486
# 1       0.741870
# 2      -1.951195
# 3       0.162197
# 4      -1.185007
#           ...
# 9563   -0.402716
# 9564   -0.866992
# 9565    1.565758
# 9566    0.647942
# 9567    0.261493
# Name: AT, Length: 9568, dtype: float64
# 0      -0.987245
# 1       0.681010
# 2      -1.172956
# 3       0.237191
# 4      -1.322470
#           ...
# 9563   -0.363223
# 9564   -1.190268
# 9565    1.575729
# 9566    1.191716
# 9567    0.646385
# Name: V, Length: 9568, dtype: float64
# 0       1.820393
# 1       1.141803
# 2      -0.185068
# 3      -0.508366
# 4      -0.678435
#           ...
# 9563    0.126444
# 9564    1.753039
# 9565   -0.057096
# 9566    0.101186
# 9567    0.668642
# Name: AP, Length: 9568, dtype: float64
# 0      -0.009519
# 1      -0.974570
# 2       1.289772
# 3       0.228148
# 4       1.596616
#           ...
# 9563    1.211692
# 9564   -0.447182
# 9565   -2.522486
# 9566   -0.747861
# 9567   -0.372526
# Name: RH, Length: 9568, dtype: float64
# ...

# %%
normalized
# Out:
# [0      -0.629486
#  1       0.741870
#  2      -1.951195
#  3       0.162197
#  4      -1.185007
#            ...
#  9563   -0.402716
#  9564   -0.866992
#  9565    1.565758
#  9566    0.647942
#  9567    0.261493
#  Name: AT, Length: 9568, dtype: float64, 0      -0.987245
#  1       0.681010
#  2      -1.172956
#  3       0.237191
#  4      -1.322470
#            ...
#  9563   -0.363223
#  9564   -1.190268
#  9565    1.575729
#  9566    1.191716
#  9567    0.646385
#  Name: V, Length: 9568, dtype: float64, 0       1.820393
#  1       1.141803
#  2      -0.185068
#  3      -0.508366
#  4      -0.678435
#            ...
#  9563    0.126444
#  9564    1.753039
#  9565   -0.057096
#  9566    0.101186
#  9567    0.668642
#  Name: AP, Length: 9568, dtype: float64, 0      -0.009519
#  1      -0.974570
#  2       1.289772
#  3       0.228148
#  4       1.596616
#            ...
#  9563    1.211692
#  9564   -0.447182
#  9565   -2.522486
#  9566   -0.747861
#  9567   -0.372526
# ...

# %%
mse_tr=[]
normalized_np=np.array(normalized)
normalized_np=normalized_np.T
xTrain, xTest, yTrain, yTest = train_test_split(normalized_np, y, test_size =0.7, random_state = 0)
for i in range(1,101):
    neigh = KNeighborsRegressor(n_neighbors=i)
    print("k=",i)
    neigh.fit(xTrain,yTrain) 
    #KNeighborsRegressor(...)
    predict_tr=neigh.predict(xTrain)
    print(predict_tr)
    #x=predict-test
    x_tr=predict_tr-yTrain
    print(abs(x_tr))
    abs_x_tr=abs(x_tr)
    print(abs_x_tr.sum())
    sum_abs_x_tr=abs_x_tr.sum()
    b_tr=sum_abs_x_tr.astype(int)
    listtt_tr.append(b_tr)
    train_error=mean_squared_error(yTrain,predict_tr)
    mse_tr.append(train_error)
print(listtt_tr)  

min_value_tr=0
for i in range (len(listtt_tr)-1):
    if listtt_tr[i]<listtt_tr[i+1]:
        tmp_tr = listtt_tr[i]
        listtt_tr[i] = listtt_tr[i+1]
        listtt_tr[i+1] = tmp_tr
        min_value_te=tmp_tr
#print("most suitable k (test errors):k=3")        
print(min_value_tr)
# Out:
# k= 1
# [477.57 439.75 478.38 ... 459.01 462.72 428.12]
# [0. 0. 0. ... 0. 0. 0.]
# 0.0
# k= 2
# [476.37  441.66  477.545 ... 464.73  461.885 428.88 ]
# [1.2   1.91  0.835 ... 5.72  0.835 0.76 ]
# 4855.17
# k= 3
# [476.62666667 437.42       479.00666667 ... 465.98333333 461.44666667
#  428.81      ]
# [0.94333333 2.33       0.62666667 ... 6.97333333 1.27333333 0.69      ]
# 6168.886666666667
# k= 4
# [475.9375 435.5925 479.16   ... 464.8825 463.155  430.1425]
# [1.6325 4.1575 0.78   ... 5.8725 0.435  2.0225]
# 6858.977500000002
# k= 5
# [478.742 435.47  477.002 ... 465.68  463.646 429.976]
# [1.172 4.28  1.378 ... 6.67  0.926 1.856]
# 7303.22
# k= 6
# [479.45333333 434.515      475.68666667 ... 465.         464.01833333
#  430.97833333]
# [1.88333333 5.235      2.69333333 ... 5.99       1.29833333 2.85833333]
# 7609.470000000003
# k= 7
# [478.23857143 433.88       474.62714286 ... 465.01285714 464.03285714
#  430.79428571]
# ...

# %%
mse=[]
normalized_np=np.array(normalized)
normalized_np=normalized_np.T
xTrain, xTest, yTrain, yTest = train_test_split(normalized_np, y, test_size =0.7, random_state = 0)
for i in range(1,101):
    neigh = KNeighborsRegressor(n_neighbors=i)
    print("k=",i)
    neigh.fit(xTrain,yTrain) 
    #KNeighborsRegressor(...)
    predict_te=neigh.predict(xTest)
    print(predict_te)
    #x=predict-test
    x_te=predict_te-yTest
    print(abs(x_te))
    abs_x_te=abs(x_te)
    print(abs_x_te.sum())
    sum_abs_x_te=abs_x_te.sum()
    b_te=sum_abs_x_te.astype(int)
    listtt_te.append(b_te)
    test_error=mean_squared_error(yTest,predict_te)
    mse.append(test_error)
print(listtt_te)  

min_value_te=0
for i in range (len(listtt_te)-1):
    if listtt_te[i]<listtt_te[i+1]:
        tmp_te = listtt_te[i]
        listtt_te[i] = listtt_te[i+1]
        listtt_te[i+1] = tmp_te
        min_value_te=tmp_te
#print("most suitable k (test errors):k=3")        
print(min_value_te)
# Out:
# k= 1
# [436.48 458.78 462.21 ... 454.13 430.91 443.82]
# [5.25 1.23 1.07 ... 1.82 0.85 1.39]
# 22794.81
# k= 2
# [434.575 458.655 465.15  ... 453.165 432.075 443.86 ]
# [3.345 1.355 4.01  ... 0.855 2.015 1.35 ]
# 21383.03
# k= 3
# [433.59       457.28       466.79       ... 452.70333333 431.
#  442.86333333]
# [2.36       2.73       5.65       ... 0.39333333 0.94       2.34666667]
# 21145.863333333327
# k= 4
# [433.6775 455.27   467.2875 ... 452.445  429.9675 444.09  ]
# [2.4475 4.74   6.1475 ... 0.135  0.0925 1.12  ]
# 21243.997499999998
# k= 5
# [433.412 456.134 467.022 ... 452.108 430.374 443.56 ]
# [2.182 3.876 5.882 ... 0.202 0.314 1.65 ]
# 21383.258
# k= 6
# [433.44833333 456.44166667 466.05166667 ... 452.49666667 429.89333333
#  443.72166667]
# [2.21833333 3.56833333 4.91166667 ... 0.18666667 0.16666667 1.48833333]
# 21457.551666666666
# k= 7
# [432.73571429 455.43285714 466.11571429 ... 452.80857143 430.92857143
#  444.23428571]
# ...

# %%
print("train error:",train_error)
# Out:
# train error: 21.812792283418123

# %%
print("test error:",test_error)
# Out:
# test error: 24.24843074631083

# %%
#k_value= np.k_value
#normalized= np.normalized
plt.plot(k_value,mse_tr, color='black');
plt.plot(k_value,mse, color='black');
plt.show()

# %% [markdown]
# #### (j) Compare the results of KNN Regression with the linear regression model that has the smallest test error and provide your analysis.

# %%
print("the k-nn Regression results were less biased than linear regression model results")
# Out:
# the k-nn Regression results were less biased than linear regression model results

# %% [markdown]
# #### 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# #### (a) The sample size n is extremely large, and the number of predic-tors p is small.

# %%
print("Better. A flexible method will fit the data closer and with the large sample size, would perform better than an inflexible approach.")
# Out:
# Better. A flexible method will fit the data closer and with the large sample size, would perform better than an inflexible approach.

# %% [markdown]
# #### (b) The number of predictors p is extremely large, and the number of observations n is small.

# %%
print("Worse. A flexible method would overfit the small number of observations.")
# Out:
# Worse. A flexible method would overfit the small number of observations.

# %% [markdown]
# #### (c) The relationship between the predictors and response is highly non-linear.¶

# %%
print("Better. With more degrees of freedom, a flexible method would fit better than an inflexible one.")
# Out:
# Better. With more degrees of freedom, a flexible method would fit better than an inflexible one.

# %% [markdown]
# #### (d) The variance of the error terms, i.e. σ2 = Var(), is extremely high.

# %%
print("Worse. A flexible method would fit to the noise in the error terms and increase variance.")
# Out:
# Worse. A flexible method would fit to the noise in the error terms and increase variance.

# %% [markdown]
# #### 7. The table below provides a training data set containing six observa-tions, three predictors, and one qualitative response variable.
# #### Obs. X1 X2 X3 Y
# #### 1 0 3 0 Red
# #### 2 2 0 0 Red
# #### 3 0 1 3 Red
# #### 4 0 1 2 Green
# #### 5 −1 0 1 Green
# #### 6 1 1 1 Red
# #### Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.¶

# %% [markdown]
# #### (a) Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.

# %%
import pandas as pd 
  
# initialize list of lists 
traindata = [[1,0,3,0,'Red'], [2,2,0,0,'Red'], [3,0,1,3,'Red'],[4,0,1,2,'Green'],[5,-1,0,1,'Green'],[6,1,1,1,'Red'],[7,0,0,0,'???']] 
  
# Create the pandas DataFrame 
df7 = pd.DataFrame(traindata, columns = ['Obs.', 'X1','X2','X3','Y']) 
  
# print dataframe. 
df7
# Out:
#    Obs.  X1  X2  X3      Y
# 0     1   0   3   0    Red
# 1     2   2   0   0    Red
# 2     3   0   1   3    Red
# 3     4   0   1   2  Green
# 4     5  -1   0   1  Green
# 5     6   1   1   1    Red
# 6     7   0   0   0    ???

# %%
df7_np=df7.to_numpy()
df7_np
# Out:
# array([[1, 0, 3, 0, 'Red'],
#        [2, 2, 0, 0, 'Red'],
#        [3, 0, 1, 3, 'Red'],
#        [4, 0, 1, 2, 'Green'],
#        [5, -1, 0, 1, 'Green'],
#        [6, 1, 1, 1, 'Red'],
#        [7, 0, 0, 0, '???']], dtype=object)

# %%
df7_np[:-1,1:-1]
# Out:
# array([[0, 3, 0],
#        [2, 0, 0],
#        [0, 1, 3],
#        [0, 1, 2],
#        [-1, 0, 1],
#        [1, 1, 1]], dtype=object)

# %%
obs1 = np.array([0,3,0])   
obsn = np.array([0,0,0])
 
dist1=np.sqrt(np.sum(np.square(obs1-obsn))) 
print(dist1)
# Out:
# 3.0

# %%
obs2 = np.array([2,0,0])   
obsn = np.array([0,0,0])
 
dist2=np.sqrt(np.sum(np.square(obs2-obsn))) 
print(dist2)
# Out:
# 2.0

# %%
obs3 = np.array([0,1,3])  
obsn = np.array([0,0,0])
 
dist3=np.sqrt(np.sum(np.square(obs3-obsn))) 
print(dist3)
# Out:
# 3.1622776601683795

# %%
obs4 = np.array([0,1,2])  
obsn = np.array([0,0,0])
 
dist4=np.sqrt(np.sum(np.square(obs4-obsn))) 
print(dist4)
# Out:
# 2.23606797749979

# %%
obs5 = np.array([-1,0,1])  
obsn = np.array([0,0,0])
 
dist5=np.sqrt(np.sum(np.square(obs5-obsn))) 
print(dist5)
# Out:
# 1.4142135623730951

# %%
obs6 = np.array([1,1,1])  
obsn = np.array([0,0,0])
 
dist6=np.sqrt(np.sum(np.square(obs6-obsn))) 
print(dist6)
# Out:
# 1.7320508075688772

# %% [markdown]
# #### (b) What is our prediction with K = 1? Why?

# %%
obs5 = np.array([-1,0,1])  
obsn = np.array([0,0,0])
 
dist5=np.sqrt(np.sum(np.square(obs5-obsn))) 
print(dist5)    
print("predict K = 1: Green")
print("because (0,0,0) has the shortest distance with (-1,0,1)")
# Out:
# 1.4142135623730951
# predict K = 1: Green
# because (0,0,0) has the shortest distance with (-1,0,1)

# %% [markdown]
# #### (c) What is our prediction with K = 3? Why?

# %%
print(dist1,dist2,dist3,dist4,dist5,dist6) 
print("Obs.2 Obs.5 Obs.6 have the three shortest distances with (0,0,0)")
print("Obs.2:Red")
print("Obs.5:Green")
print("Obs.6:Red")
print("predict K = 3: Red")
print("because Red is the most frequent among the three above")
# Out:
# 3.0 2.0 3.1622776601683795 2.23606797749979 1.4142135623730951 1.7320508075688772
# Obs.2 Obs.5 Obs.6 have the three shortest distances with (0,0,0)
# Obs.2:Red
# Obs.5:Green
# Obs.6:Red
# predict K = 3: Red
# because Red is the most frequent among the three above

# %% [markdown]
# #### (d) If the Bayes decision boundary in this problem is highly non-linear, then would we expect the best value for K to be large or small? Why?

# %%
print("As K becomes larger, the boundary becomes inflexible (linear). So in this case we would expect the best value for K to be small.")
# Out:
# As K becomes larger, the boundary becomes inflexible (linear). So in this case we would expect the best value for K to be small.
